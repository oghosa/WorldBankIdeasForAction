# %% [markdown]
# <a href="https://colab.research.google.com/github/oghosa/WorldBankIdeasForAction/blob/master/ideaForAction_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import nltk
import re
import os
import io
import codecs
from sklearn import feature_extraction
from google.colab import files
#import mpld3

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-afb38a67-4113-4286-a83c-0fb8550f8fbb" name="files[]" multiple disabled />
#      <output id="result-afb38a67-4113-4286-a83c-0fb8550f8fbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PastWinningIdeas.csv to PastWinningIdeas.csv

# %%
ideas = pd.read_csv('PastWinningIdeas.csv', encoding = "ISO-8859-1")

# %%
ideas['Full Abstract'].head(50)
# Out:
# 0     Remittances represent significant financial fl...
# 1     The goal of the proposal is to provide a pract...
# 2     Although mining gives governments in many coun...
# 3     Millions of people in developing countries use...
# 4     Impact.PH seeks to drive strategic philanthrop...
# 5     Realizing new modalities for funding developme...
# 6     Our proposal was first sent to the contest of ...
# 7     We propose the application of Development Impa...
# 8     We identify return migrants as an optimal grou...
# 9     The post-2015 development agenda will be adopt...
# 10    Industrial energy provision from the power gri...
# 11    Roughly 10 percent of all research and develop...
# 12    Our vision: We believe that people are born eq...
# 13    Global remittances exceed the size of global d...
# 14    Efforts to support innovation and entrepreneur...
# 15    Surya addresses the prevalence of diesel-power...
# 16    There is a growing despair syndrome in Africa ...
# 17    The project involves the consolidation of a mu...
# 18    Logistics and supply chains are the wheels of ...
# 19    Oincs is a mobile platform that aims to look a...
# 20    NaukriSearch is a dual platform employment ser...
# 21    The life insurance market for women is large, ...
# 22    Green Bonds combine fixed income financial ins...
# 23    An important driver of achieving Sustainable D...
# 24    In order to improve business environments in d...
# 25    We observed that with the increasing popularit...
# 26    During the period from 2012 to 2014, the numbe...
# 27    Centralized financial systems have formed the ...
# 28    Most of the worlds poorest people are smallho...
# 29    The Gifted Hands Network turns problems into o...
# 30    Bihar, India, has more than 9,000 square kilom...
# 31    Project Forward is an innovative, self-sustain...
# 32    Sanitation means more than just the improvemen...
# 33    The nonprofit foundation She-Is empowers women...
# 34    Over two-thirds of developing countries econo...
# 35    The growth of small and medium-sized enterpris...
# 36    The use of blood and blood products has become...
# 37    Achieving the United Nations sustainable deve...
# 38    Two-thirds of the people in Asia are undernour...
# 39    Rwandas population has more than doubled over...
# 40    During the past several decades, the world has...
# 41    The Al-Derb platform1 provides a way for indiv...
# 42    Addressing food safety is not only a serious g...
# 43    Every year, more than 8 million metric tons of...
# 44    Wood and charcoal are major sources of domesti...
# 45    Credit Locus is a virtual platform that matche...
# 46    One of the biggest challenges faced by entrepr...
# 47    In the past decade, there has been a rapid gro...
# 48    Discrimination against women and girls and gen...
# 49                                                  NaN
# Name: Full Abstract, dtype: object

# %%
ideas_compact = ideas.iloc[:49, :13]
ideas_compact.shape
# Out:
# (49, 13)

# %%
ideas_compact.head()
# Out:
#   Project ID    Year  Year Project Number  \
# 0     2015-1  2015.0                  1.0
# 1     2015-2  2015.0                  2.0
# 2     2015-3  2015.0                  3.0
# 3     2015-4  2015.0                  4.0
# 4     2015-5  2015.0                  5.0
#
#                                         Project Name  \
# 0  Creating New Microinsurance Products for Remit...
# 1  Innovative PPP (public-private partnership) Mo...
# 2  Decreasing Poverty in the Mining Communities o...
# 3  Development Impact BondsThe Power of Particip...
# 4  Impact.PH: An Initiative to Enhance and Transf...
#
#                                        Document Link Legitimacy Website Link  \
# 0  https://openknowledge.worldbank.org/bitstream/...        NaN          NaN
# 1                                                NaN        NaN          NaN
# 2                                                NaN        NaN          NaN
# 3                                                NaN        NaN          NaN
# 4                                                NaN        NaN          NaN
#
#       Country                                  Topic Area  \
# 0       India                Remittance, \nMicroinsurance
# 1     Nigeria                                 Agricluture
# 2        Peru                                      Mining
# 3         NaN  Development Impact Bonds (DIBs), \nCooking
# 4  Philippine                            Data, Infomation
#
#                                                Notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  - Broad scope to all developing nations that u...
# 4  - " drive strategic philanthropy and become th...
#
#                                        Full Abstract Rank  \
# 0  Remittances represent significant financial fl...    1
# 1  The goal of the proposal is to provide a pract...    2
# 2  Although mining gives governments in many coun...    3
# 3  Millions of people in developing countries use...    4
# 4  Impact.PH seeks to drive strategic philanthrop...    5
#
#            Tech-Solution
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4  Yes - Online Database

# %%
nltk.download('stopwords')
nltk.download('punkt')
stopwords = nltk.corpus.stopwords.words('english')
stopwords[:10]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
# load nltk's SnowballStemmer as variabled 'stemmer'
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
# here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed

def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
titles = ideas_compact['Project Name']
abstracts = ideas_compact['Full Abstract']

# %%
titles.head()
#abstracts.head()
# Out:
# 0    Creating New Microinsurance Products for Remit...
# 1    Innovative PPP (public-private partnership) Mo...
# 2    Decreasing Poverty in the Mining Communities o...
# 3    Development Impact BondsThe Power of Particip...
# 4    Impact.PH: An Initiative to Enhance and Transf...
# Name: Project Name, dtype: object

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in abstracts:
    allwords_stemmed = tokenize_and_stem(i) #for each item in 'synopses', tokenize/stem
    totalvocab_stemmed.extend(allwords_stemmed) #extend the 'totalvocab_stemmed' list
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
print('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
# Out:
# there are 12005 items in vocab_frame

# %%
vocab_frame.head()
# Out:
#                 words
# remitt    remittances
# repres      represent
# signific  significant
# financi     financial
# flow            flows

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 min_df=0.2, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

# %time tfidf_matrix = tfidf_vectorizer.fit_transform(abstracts) #fit the vectorizer to synopses

print(tfidf_matrix.shape)
# Out:
# CPU times: user 370 ms, sys: 11.2 ms, total: 381 ms
# Wall time: 388 ms
# (49, 85)

# %%
#terms is just a list of the features used in the tf-idf matrix. This is a vocabulary
terms = tfidf_vectorizer.get_feature_names()
terms
# Out:
# ['access',
#  'activ',
#  'address',
#  'aim',
#  'avail',
#  'becaus',
#  'becom',
#  'busi',
#  'challeng',
#  'communiti',
#  'cost',
#  'countri',
#  'creat',
#  'current',
#  'custom',
#  'develop goal',
#  'econom',
#  'effect',
#  'enabl',
#  'encourag',
#  'exist',
#  'face',
#  'financ',
#  'financi',
#  'focus',
#  'fund',
#  'global',
#  'goal',
#  'govern',
#  'growth',
#  'health',
#  'help',
#  'high',
#  'howev',
#  'implement',
#  'improv',
#  'includ',
#  'increas',
#  'ing',
#  'initi',
#  'innov',
#  'institut',
#  'lack',
#  'local',
#  'make',
#  'mani',
#  'market',
#  'model',
#  'nation',
#  'need',
#  'new',
#  'onli',
#  'opportun',
#  'organ',
#  'past',
#  'peopl',
#  'percent',
#  'platform',
#  'popul',
#  'potenti',
#  'problem',
#  'process',
#  'product',
#  'program',
#  'project',
#  'propos',
#  'provid',
#  'region',
#  'resourc',
#  'sector',
#  'secur',
#  'servic',
#  'social',
#  'solut',
#  'sourc',
#  'support',
#  'sustain',
#  'sustain develop',
#  'technolog',
#  'tion',
#  'unit',
#  'use',
#  'work',
#  'world',
#  'year']

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)

# %% [markdown]
# # Clustering
# Here I cluster the projects into 5 groups based on their abstracts using k-means clustering for the grouping and tf-idf for the document similarity scoring.

# %% [markdown]
# Here, I define term frequency-inverse document frequency (tf-idf) vectorizer parameters and then convert the abstracts list into a tf-idf matrix.
#
# To get a Tf-idf matrix, first count word occurrences by document. This is transformed into a document-term matrix (dtm). This is also just called a term frequency matrix. An example of a dtm is below.
#
# ![document-term matrix (dtm)](http://www.jiem.org/index.php/jiem/article/viewFile/293/252/2402)
#
# Then apply the term frequency-inverse document frequency weighting: words that occur frequently within a document but not frequently within the corpus receive a higher weighting as these words are assumed to contain more meaning in relation to the document.
#
# A couple things to note about the parameters I define below:
#
# * **max_df:** this is the maximum frequency within the documents a given feature can have to be used in the tfi-idf matrix. If the term is in greater than 80% of the documents it probably cares little meanining (in the context of film synopses)
# * **min_idf:** this could be an integer (e.g. 5) and the term would have to be in at least 5 of the documents to be considered. Here I pass 0.2; the term must be in at least 20% of the document. I found that if I allowed a lower min_df I ended up basing clustering on names--for example "Michael" or "Tom" are names found in several of the movies and the synopses use these names frequently, but the names carry no real meaning.
# * **ngram_range:** this just means I'll look at unigrams, bigrams and trigrams. See n-grams

# %%
from sklearn.cluster import KMeans

num_clusters = 5

km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)

clusters = km.labels_.tolist()
# Out:
# CPU times: user 68.7 ms, sys: 0 ns, total: 68.7 ms
# Wall time: 69.1 ms

# %%
from sklearn.externals import joblib

#uncomment the below to save your model 
#since I've already run my model I am loading from the pickle

joblib.dump(km,  'doc_cluster.pkl')

#km = joblib.load('doc_cluster.pkl')
clusters = km.labels_.tolist()

# %%
clusters
# Out:
# [4,
#  4,
#  1,
#  4,
#  2,
#  1,
#  1,
#  1,
#  3,
#  2,
#  1,
#  3,
#  4,
#  1,
#  2,
#  1,
#  1,
#  2,
#  3,
#  0,
#  3,
#  3,
#  1,
#  2,
#  4,
#  1,
#  3,
#  1,
#  4,
#  4,
#  4,
#  2,
#  4,
#  2,
#  3,
#  1,
#  4,
#  0,
#  0,
#  4,
#  1,
#  4,
#  0,
#  4,
#  2,
#  3,
#  4,
#  3,
#  4]

# %%
ideas_compact['Cluster'] = clusters
ideas_compact
# Out:
#    Project ID    Year  Year Project Number  \
# 0      2015-1  2015.0                  1.0
# 1      2015-2  2015.0                  2.0
# 2      2015-3  2015.0                  3.0
# 3      2015-4  2015.0                  4.0
# 4      2015-5  2015.0                  5.0
# 5      2015-6  2015.0                  6.0
# 6      2015-7  2015.0                  7.0
# 7      2015-8  2015.0                  8.0
# 8      2015-9  2015.0                  9.0
# 9     2015-10  2015.0                 10.0
# 10    2015-11  2015.0                 11.0
# 11    2015-12  2015.0                 12.0
# 12    2015-13  2015.0                 13.0
# 13    2015-14  2015.0                 14.0
# 14    2015-15  2015.0                 15.0
# 15    2015-16  2015.0                 16.0
# 16    2015-17  2015.0                 17.0
# 17    2015-18  2015.0                 18.0
# 18     2016-1  2016.0                  1.0
# 19     2016-2  2016.0                  2.0
# 20     2016-3  2016.0                  3.0
# 21     2016-4  2016.0                  4.0
# 22     2016-5  2016.0                  5.0
# 23     2016-6  2016.0                  6.0
# 24     2016-7  2016.0                  7.0
# 25     2016-8  2016.0                  8.0
# 26     2016-9  2016.0                  9.0
# 27    2016-10  2016.0                 10.0
# 28     2017-1  2017.0                  1.0
# 29     2017-2  2017.0                  2.0
# 30     2017-3  2017.0                  3.0
# 31     2017-4  2017.0                  4.0
# 32     2017-5  2017.0                  5.0
# 33     2017-6  2017.0                  6.0
# 34     2017-7  2017.0                  7.0
# 35     2017-8  2017.0                  8.0
# 36     2017-9  2017.0                  9.0
# 37    2017-10  2017.0                 10.0
# 38     2018-1  2018.0                  1.0
# 39     2018-2  2018.0                  2.0
# 40     2018-3  2018.0                  3.0
# 41     2018-4  2018.0                  4.0
# 42     2018-5  2018.0                  5.0
# 43     2018-6  2018.0                  6.0
# 44     2018-7  2018.0                  7.0
# 45     2018-8  2018.0                  8.0
# 46     2018-9  2018.0                  9.0
# 47    2018-10  2018.0                 10.0
# 48    2018-11  2018.0                 11.0
#
#                                          Project Name  \
# 0   Creating New Microinsurance Products for Remit...
# 1   Innovative PPP (public-private partnership) Mo...
# 2   Decreasing Poverty in the Mining Communities o...
# 3   Development Impact BondsThe Power of Particip...
# 4   Impact.PH: An Initiative to Enhance and Transf...
# 5   Introducing Internet-Based Funding Mechanisms ...
# 6   Biodiversity Ambassadors: Strategies for Bette...
# 7   Development Impact Bonds: Financing the Treatm...
# 8   Diaspora Bonds for Small-Business Promotion: I...
# 9   Ensuring Effective Implementation of Domestic ...
# 10  Group Captive Power Plants in Small and Medium...
# 11       A Hybrid Financing Model for Orphan Diseases
# 12  Improving Chinas Health System: Using Interne...
# 13  The International Remittance Foundation: An In...
# 14  Shark Tank Africa: Inspiring Innovators and Ec...
# 15  Surya: A Public-Private Partnership Model for ...
# 16  Tit for Tatting: Empowering Community End User...
# 17                    Vote for Ideas, Not Politicians
# 18  A Peer-to-Peer Hyperlocal Approach to Last-Mil...
# 19  OINCS: Using a Collaborative and Community Dri...
# 20  Increasing Transparency  in Indian Slum Labor ...
# 21  HerLife: A Term Life Insurance Product for Wor...
# 22  Innovative Floating Rate Green Bond for the Re...
# 23  A New Model for Impact Investing:\nApplication...
# 24  A Novel Practice for Mobile Money Payments: Us...
# 25  Agency Organization System: A Financing Model ...
# 26  Improving the Quality of Life for Artisans fro...
# 27  Reinventing Global Payment Processing for Migr...
# 28  Creating Kitovu: A Web/Mobile- Based Decentral...
# 29  Reducing Breast Cancer Death Rates among Women...
# 30  Converting Unproductive, Waterlogged Land into...
# 31  Encouraging Volunteerism Using a Proprietary D...
# 32  Portable Toilet Solution: Sustainable Sanitati...
# 33  A Socio-productive Model for Entrepreneurial E...
# 34  Commodity Bonds: A Practical Solution to Crisi...
# 35  Filling the Credit Gap: Improving SME Accounti...
# 36  Innovative Solutions to a Sustainable Blood Su...
# 37  Wicked Problems, Simple Solutions, and a New G...
# 38  The Implementation of Advanced Water Treatment...
# 39  Starlight: A Start-Up Company Based in Rwanda ...
# 40  Automated Legal Document Generation: Empowerin...
# 41  Crowdfunding Can Serve as a Pathway to Higher ...
# 42  Ensuring Food Safety in China and Beyond throu...
# 43  Concrete from Plastics? Preserve Natural Resou...
# 44  Effort Provides Sustainable Energy by Turning ...
# 45  In Ghana, Data Analytics Will Match Business E...
# 46  Mentorship Mobile App to Support Entrepreneurs...
# 47  Reduce Trash from E-Commerce Packaging and Imp...
# 48  With SafePal, Confidentially Report Gender Vio...
#
#                                         Document Link          Legitimacy  \
# 0   https://openknowledge.worldbank.org/bitstream/...                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6                                                 NaN  Functional Company
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
# 24                                                NaN                 NaN
# 25                                                NaN                 NaN
# 26                                                NaN                 NaN
# 27                                                NaN                 NaN
# 28                                                NaN                 NaN
# 29                                                NaN                 NaN
# 30                                                NaN                 NaN
# 31                                                NaN                 NaN
# 32                                                NaN                 NaN
# 33                                                NaN                 NaN
# 34                                                NaN                 NaN
# 35                                                NaN                 NaN
# 36                                                NaN                 NaN
# 37                                                NaN                 NaN
# 38                                                NaN                 NaN
# 39                                                NaN                 NaN
# 40                                                NaN                 NaN
# 41                                                NaN                 NaN
# 42                                                NaN                 NaN
# 43                                                NaN                 NaN
# 44                                                NaN                 NaN
# 45                                                NaN                 NaN
# 46                                                NaN                 NaN
# 47                                                NaN                 NaN
# 48                                                NaN                 NaN
#
#                        Website Link       Country  \
# 0                               NaN         India
# 1                               NaN       Nigeria
# 2                               NaN          Peru
# 3                               NaN           NaN
# 4                               NaN    Philippine
# 5                               NaN           NaN
# 6   http://www.ecoexperiencias.com/        Mexico
# 7                               NaN       Nigeria
# 8                               NaN           NaN
# 9                               NaN           NaN
# 10                              NaN         India
# 11                              NaN           NaN
# 12                              NaN         China
# 13                              NaN           NaN
# 14                              NaN           NaN
# 15                              NaN         India
# 16                              NaN           NaN
# 17                              NaN           NaN
# 18                              NaN       Nigeria
# 19                              NaN           NaN
# 20                              NaN           NaN
# 21                              NaN         China
# 22                              NaN         China
# 23                              NaN         Kenya
# 24                              NaN         India
# 25                              NaN         China
# 26                              NaN        Mexico
# 27                              NaN           NaN
# 28                              NaN       Nigeria
# 29                              NaN        Uganda
# 30                              NaN         India
# 31                              NaN            US
# 32                              NaN  Philiippines
# 33                              NaN      Colombia
# 34                              NaN           NaN
# 35                              NaN           NaN
# 36                              NaN       Nigeria
# 37                              NaN           NaN
# 38                              NaN           NaN
# 39                              NaN        Rwanda
# 40                              NaN           NaN
# 41                              NaN           NaN
# 42                              NaN         China
# 43                              NaN           NaN
# 44                              NaN      Tanzania
# 45                              NaN         Ghana
# 46                              NaN          Gaza
# 47                              NaN         China
# 48                              NaN        Uganda
#
#                                            Topic Area  \
# 0                        Remittance, \nMicroinsurance
# 1                                         Agricluture
# 2                                              Mining
# 3          Development Impact Bonds (DIBs), \nCooking
# 4                                    Data, Infomation
# 5                           World Bank,\nCrowdfunding
# 6                           Biodiversity, \nGovernace
# 7   Development Impact Bonds (DIBs), \nTropical Di...
# 8                 Return Migrants, Skills Development
# 9                Domestic Resource Mobilization (DRM)
# 10                                             Energy
# 11                                         Healthcare
# 12                                         Healthcare
# 13                                         Remittance
# 14                                                NaN
# 15                                  Agriculture,\nPPP
# 16                                      Public Policy
# 17                                    Politics,\nVote
# 18                                          Logistics
# 19                                    Public Security
# 20                                                NaN
# 21                                Term Life Insurance
# 22                                      Air Pollution
# 23                                   Impact Investing
# 24                            Payments, \nFigerprints
# 25                                  e-Waste Recycling
# 26                                   Women Empoerment
# 27                      Remittances,\nGlobal Payments
# 28                          Agriculture,\nWarehousing
# 29                            Healthcare,\nEmployment
# 30                     Fish Farming,\nEconomic Growth
# 31                     Volunterism,\nDigital currency
# 32                                            Toilets
# 33                                   Women Empoerment
# 34                                              Bonds
# 35                                                NaN
# 36                           Supplychain,\nHealthcare
# 37                                             Skills
# 38                        Agriculture,\nFood security
# 39                    Women Empoerment,\nSTEM,\nSolar
# 40                           Women Empoerment,\nLegal
# 41                                          Education
# 42                         Food Security,\nBlockchain
# 43                          Enviroment,\nConstruction
# 44                                             Energy
# 45                           Data Analytics,\nLending
# 46                                         Mentorship
# 47                            Environment,\nPackaging
# 48                                  Women Empowerment
#
#                                                 Notes  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   - Broad scope to all developing nations that u...
# 4   - " drive strategic philanthropy and become th...
# 5   - "This proposal outlines how the World Bank c...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9     - Focus on Domestic Resource Mobilization (DRM)
# 10  - We propose an alternative by setting up pool...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  - This idea explores the development of a symb...
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
#
#                                         Full Abstract  \
# 0   Remittances represent significant financial fl...
# 1   The goal of the proposal is to provide a pract...
# 2   Although mining gives governments in many coun...
# 3   Millions of people in developing countries use...
# 4   Impact.PH seeks to drive strategic philanthrop...
# 5   Realizing new modalities for funding developme...
# 6   Our proposal was first sent to the contest of ...
# 7   We propose the application of Development Impa...
# 8   We identify return migrants as an optimal grou...
# 9   The post-2015 development agenda will be adopt...
# 10  Industrial energy provision from the power gri...
# 11  Roughly 10 percent of all research and develop...
# 12  Our vision: We believe that people are born eq...
# 13  Global remittances exceed the size of global d...
# 14  Efforts to support innovation and entrepreneur...
# 15  Surya addresses the prevalence of diesel-power...
# 16  There is a growing despair syndrome in Africa ...
# 17  The project involves the consolidation of a mu...
# 18  Logistics and supply chains are the wheels of ...
# 19  Oincs is a mobile platform that aims to look a...
# 20  NaukriSearch is a dual platform employment ser...
# 21  The life insurance market for women is large, ...
# 22  Green Bonds combine fixed income financial ins...
# 23  An important driver of achieving Sustainable D...
# 24  In order to improve business environments in d...
# 25  We observed that with the increasing popularit...
# 26  During the period from 2012 to 2014, the numbe...
# 27  Centralized financial systems have formed the ...
# 28  Most of the worlds poorest people are smallho...
# 29  The Gifted Hands Network turns problems into o...
# 30  Bihar, India, has more than 9,000 square kilom...
# 31  Project Forward is an innovative, self-sustain...
# 32  Sanitation means more than just the improvemen...
# 33  The nonprofit foundation She-Is empowers women...
# 34  Over two-thirds of developing countries econo...
# 35  The growth of small and medium-sized enterpris...
# 36  The use of blood and blood products has become...
# 37  Achieving the United Nations sustainable deve...
# 38  Two-thirds of the people in Asia are undernour...
# 39  Rwandas population has more than doubled over...
# 40  During the past several decades, the world has...
# 41  The Al-Derb platform1 provides a way for indiv...
# 42  Addressing food safety is not only a serious g...
# 43  Every year, more than 8 million metric tons of...
# 44  Wood and charcoal are major sources of domesti...
# 45  Credit Locus is a virtual platform that matche...
# 46  One of the biggest challenges faced by entrepr...
# 47  In the past decade, there has been a rapid gro...
# 48  Discrimination against women and girls and gen...
#
#                        Rank          Tech-Solution  Cluster
# 0                         1                    NaN        4
# 1                         2                    NaN        4
# 2                         3                    NaN        1
# 3                         4                    NaN        4
# 4                         5  Yes - Online Database        2
# 5                         6     Yes - Crowdfunding        1
# 6   NA - Honourable mention                    NaN        1
# 7   NA - Honourable mention                    NaN        1
# 8   NA - Honourable mention                    NaN        3
# 9   NA - Honourable mention                    NaN        2
# 10  NA - Honourable mention                    NaN        1
# 11  NA - Honourable mention                    NaN        3
# 12  NA - Honourable mention                    NaN        4
# 13  NA - Honourable mention                    NaN        1
# 14  NA - Honourable mention                    NaN        2
# 15  NA - Honourable mention                    NaN        1
# 16  NA - Honourable mention                    NaN        1
# 17  NA - Honourable mention                    NaN        2
# 18                        1             Yes - Uber        3
# 19                        2          Yes - app/web        0
# 20                        3                    NaN        3
# 21                        4                    NaN        3
# 22                        5                    NaN        1
# 23                        6                    NaN        2
# 24  NA - Honourable mention           Yes - Mobile        4
# 25  NA - Honourable mention                    NaN        1
# 26  NA - Honourable mention                    NaN        3
# 27  NA - Honourable mention                    NaN        1
# 28                        1       Yes - Web/Mobile        4
# 29                        2                    NaN        4
# 30                        3                    NaN        4
# 31                        4                    NaN        2
# 32                        5                    NaN        4
# 33                        6                    NaN        2
# 34  NA - Honourable mention                    NaN        3
# 35  NA - Honourable mention                    NaN        1
# 36  NA - Honourable mention                    NaN        4
# 37  NA - Honourable mention                    NaN        0
# 38                        1                    NaN        0
# 39                        2                    NaN        4
# 40                        3                    NaN        1
# 41                        4                    NaN        4
# 42                        5                    NaN        0
# 43  NA - Honourable mention                    NaN        4
# 44  NA - Honourable mention                    NaN        2
# 45  NA - Honourable mention                    NaN        3
# 46  NA - Honourable mention                    NaN        4
# 47  NA - Honourable mention                    NaN        3
# 48  NA - Honourable mention                    NaN        4

# %%
ideas_compact['Cluster'].value_counts() #number of projects per cluster (clusters from 0 to 4)
# Out:
# 4    15
# 1    13
# 3     9
# 2     8
# 0     4
# Name: Cluster, dtype: int64

# %%
grouped = ideas_compact['Year Project Number'].groupby(ideas_compact['Cluster']) #groupby cluster for aggregation purposes

grouped.mean()
# Out:
# Cluster
# 0    4.500000
# 1    8.923077
# 2    8.875000
# 3    7.000000
# 4    5.266667
# Name: Year Project Number, dtype: float64

# %%
from __future__ import print_function

print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :6]: #print top 6 words that are nearest to the cluster centroid. 
        print(' %s' % vocab_frame.loc[terms[ind].split(' ')].values.tolist()[0][0], end=',')
    print() #add whitespace
    
    print("Cluster %d titles:" % i)
    for name in ideas_compact.loc[ideas_compact['Cluster'].isin([i])]['Project Name'].tolist():
      print(' %s' %name)
    print() #add whitespace
    print() #add whitespace
    
print()
print()
# Out:
# Top terms per cluster:
#
# Cluster 0 words: secure, technology, goal, addressed, communities, sustainable,
# Cluster 0 titles:
#  OINCS: Using a Collaborative and Community Driven Approach to Citizen Mobility and Security
#  Wicked Problems, Simple Solutions, and a New Generation of Changemakers
#  The Implementation of Advanced Water Treatment Technology in Aquaculture to Ensure Sustainable Development for World Food Security
#
#  Ensuring Food Safety in China and Beyond through Blockchain Technology
#
#
# Cluster 1 words: proposal, financing, government, local, projects, using,
# Cluster 1 titles:
#  Decreasing Poverty in the Mining Communities of the World through the Empowerment of Communities in the Control of Mining Royalty Funds: An Application to the Peruvian Case
#  Introducing Internet-Based Funding Mechanisms for World Bank Operations
#  Biodiversity Ambassadors: Strategies for Better Governance of Biodiversity through the Participation of Children and Youth with the Expansion of Ecoexperiencias in Mesoamerica
#  Development Impact Bonds: Financing the Treatment of Neglected Tropical Diseases in Sub-Saharan Africa
#  Group Captive Power Plants in Small and Medium-Scale Industrial Clusters in India
#  The International Remittance Foundation: An Innovative Way to Mobilize Remittances for Economic Development and Bring the Most Basic Services to the Poor
#  Surya: A Public-Private Partnership Model for Agricultural Development in India
#  Tit for Tatting: Empowering Community End Users in Determining Resource Use and Allocation for Domestic Resource Mobilization and Improved Efficiency in Public Spending
#  Innovative Floating Rate Green Bond for the Reduction of Air Pollution in ChinaAn Application to the Shanxi Provinces Case
#  Agency Organization System: A Financing Model for Revolutionizing the e-Waste Recycling Business in Guiyu, China
#  Reinventing Global Payment Processing for Migrant Remittances, Microenterprise Funding Infusions and Nationwide Direct Benefit Transfers (DBTs)
#  Filling the Credit Gap: Improving SME Accounting Standards and Data Collection in India
#  Automated Legal Document Generation: Empowering MENA Women to Exercise Their Legal Right
#
#
# Cluster 2 words: social, innovations, effectiveness, model, united, goal,
# Cluster 2 titles:
#  Impact.PH: An Initiative to Enhance and Transform the Philippine Nonprofit Sector
#  Ensuring Effective Implementation of Domestic Resource Mobilization for Successful Delivery of the Post-2015 Development Agenda in Africa
#  Shark Tank Africa: Inspiring Innovators and Ecosystems through Aspirational Media
#  Vote for Ideas, Not Politicians
#  A New Model for Impact Investing:
# Application of Impact  Units to Assess Feasibility of Social Investment Opportunities and Interventions in Kenya
#
#  Encouraging Volunteerism Using a Proprietary Digital-Currency Incentive
#
#  A Socio-productive Model for Entrepreneurial Education and the Promotion of Business Activity for Women Who Are Victims of Armed Conflict
#  Effort Provides Sustainable Energy by Turning Biomass to Charcoal in Tanzania
#
#
# Cluster 3 words: markets, solution, productive, platforms, world, potential,
# Cluster 3 titles:
#  Diaspora Bonds for Small-Business Promotion: Integrating Return Migrants in Developing Countries
#  A Hybrid Financing Model for Orphan Diseases
#  A Peer-to-Peer Hyperlocal Approach to Last-Mile Delivery in Nigeria
#  Increasing Transparency  in Indian Slum Labor Markets: Providing Access to Employment Information
#  HerLife: A Term Life Insurance Product for Working Mothers in China
#  Improving the Quality of Life for Artisans from Rural Communities through Empowerment of Women
#  Commodity Bonds: A Practical Solution to Crisis Vulnerability in Commodity- Dependent Developing Countries
#  In Ghana, Data Analytics Will Match Business Enterprises with Lending Institutions
#  Reduce Trash from E-Commerce Packaging and Improve Chinas Environment
#
#
# Cluster 4 words: accessing, people, health, percent, providers, using,
# Cluster 4 titles:
#  Creating New Microinsurance Products for Remittance Service Providers in India
#  Innovative PPP (public-private partnership) Model for Promoting Financial Deepening and Inclusion in the Rice Value Chain in Nigeria
#  Development Impact BondsThe Power of Participatory Development in Creating Sustainable Market Demand:A Case Study of Open Fires and Inefficient Cookstoves
#  Improving Chinas Health System: Using Internet Finance to Broaden Access and Affordability
#  A Novel Practice for Mobile Money Payments: Using Fingerprints to Enable Real-Time Transactions in Nelamangala, India
#  Creating Kitovu: A Web/Mobile- Based Decentralized Fertilizer and Seedling Warehousing System That Increases Crop Yields in Nigeria by Matching the Right Inputs to the Right Soils
#  Reducing Breast Cancer Death Rates among Women in Uganda and Increasing the Employability of Visually Impaired Women
#
#  Converting Unproductive, Waterlogged Land into Productive Fish Farming Units to Generate Sustainable Livelihoods, Provide Food Security, and Develop Critical Avenues for Economic Growth for Local Rural Communities
#  Portable Toilet Solution: Sustainable Sanitation for the Base of the Pyramid
#  Innovative Solutions to a Sustainable Blood Supply Chain Management System: A Technology-Driven Donor Management System in Nigeria
#  Starlight: A Start-Up Company Based in Rwanda That Aims to End the Use of Kerosene Lamps in Rural Villages by Providing Solar-Powered Lanterns to These Communities and by Rolling Out a STEM Program That Empowers Female Students
#
#  Crowdfunding Can Serve as a Pathway to Higher Education
#  Concrete from Plastics? Preserve Natural Resources and Produce Sustainable Construction Materials
#  Mentorship Mobile App to Support Entrepreneurs in West Bank and Gaza
#  With SafePal, Confidentially Report Gender Violence and Access Health and Social Services
